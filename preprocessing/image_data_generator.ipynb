# %%
# %matplotlib inline

# %%
from __future__ import print_function

from scipy import misc
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
face = misc.face()
print(face.shape)
face = misc.imresize(face, (768, 768))
plt.imshow(face)
plt.show()
# Out:
# (768, 1024, 3)

# %%
x = img_to_array(face)
x = x.reshape((1,) + x.shape)

# %%
def show_flow_image(datagen, x, show_num):
    i = 0
    for batch in datagen.flow(x, x, batch_size=1): # second args 'x' is dummy of y
        array = batch[0][0,:,:,:]
        img = array_to_img(array)
        index = 251 + i
        plt.subplot(index)
        plt.imshow(img)
        i += 1
        if i >= show_num: break
    plt.show()

# %%
# samplewise_center = True
datagen = ImageDataGenerator(samplewise_center=True)
show_flow_image(datagen, x, 1)

# %%
# samplewise_std_normalization = True
datagen = ImageDataGenerator(samplewise_std_normalization=True)
show_flow_image(datagen, x, 1)

# %%
# rotation_range = 0
datagen = ImageDataGenerator(rotation_range=0)
show_flow_image(datagen, x, 10)

# %%
# rotation_range = 60
datagen = ImageDataGenerator(rotation_range=60)
show_flow_image(datagen, x, 10)

# %%
# rotation_range = 120
datagen = ImageDataGenerator(rotation_range=120)
show_flow_image(datagen, x, 10)

# %%
# rotation_range = 180
datagen = ImageDataGenerator(rotation_range=180)
show_flow_image(datagen, x, 10)

# %%
# width_shift_range = 0.2
datagen = ImageDataGenerator(width_shift_range=0.2)
show_flow_image(datagen, x, 10)

# %%
# width_shift_range = 0.5
datagen = ImageDataGenerator(width_shift_range=0.5)
show_flow_image(datagen, x, 10)

# %%
# width_shift_range = 0.8
datagen = ImageDataGenerator(width_shift_range=0.8)
show_flow_image(datagen, x, 10)

# %%
# shear_range = 0.2
datagen = ImageDataGenerator(shear_range=0.2)
show_flow_image(datagen, x, 10)

# %%
# shear_range = 0.5
datagen = ImageDataGenerator(shear_range=0.5)
show_flow_image(datagen, x, 10)

# %%
# shear_range = 0.8
datagen = ImageDataGenerator(shear_range=0.8)
show_flow_image(datagen, x, 10)

# %%
# zoom_range = 0.2
datagen = ImageDataGenerator(zoom_range=0.2)
show_flow_image(datagen, x, 10)

# %%
# zoom_range = 0.5
datagen = ImageDataGenerator(zoom_range=0.5)
show_flow_image(datagen, x, 10)

# %%
# zoom_range = 0.8
datagen = ImageDataGenerator(zoom_range=0.8)
show_flow_image(datagen, x, 10)

# %%
# zoom_range [lower = 0.0, upper = 0.5]
datagen = ImageDataGenerator(zoom_range=[0.0, 0.5])
show_flow_image(datagen, x, 10)

# %%
# zoom_range [lower = 0.5, upper = 1.0]
datagen = ImageDataGenerator(zoom_range=[0.5, 1.0])
show_flow_image(datagen, x, 10)

# %%
# zoom_range [lower = 1.0, upper = 1.5]
datagen = ImageDataGenerator(zoom_range=[1.0, 1.5])
show_flow_image(datagen, x, 10)

# %%
# zoom_range [lower = 0.5, upper = 1.5]
datagen = ImageDataGenerator(zoom_range=[0.5, 1.5]) # It is equivalent to zoom_range=0.5
show_flow_image(datagen, x, 10)

# %%
# channel_shift_range = 10
datagen = ImageDataGenerator(channel_shift_range=10)
show_flow_image(datagen, x, 10)

# %%
# channel_shift_range = 50
datagen = ImageDataGenerator(channel_shift_range=50)
show_flow_image(datagen, x, 10)

# %%
# channel_shift_range = 100
datagen = ImageDataGenerator(channel_shift_range=100)
show_flow_image(datagen, x, 10)

# %%
# channel_shift_range = 200
datagen = ImageDataGenerator(channel_shift_range=200)
show_flow_image(datagen, x, 10)

# %%
# fill_mode = "constant"
datagen = ImageDataGenerator(width_shift_range=0.5, fill_mode="constant")
show_flow_image(datagen, x, 10)

# %%
# fill_mode = "nearest"
datagen = ImageDataGenerator(width_shift_range=0.5, fill_mode="nearest")
show_flow_image(datagen, x, 10)

# %%
# fill_mode = "reflect"
datagen = ImageDataGenerator(width_shift_range=0.5, fill_mode="reflect")
show_flow_image(datagen, x, 10)

# %%
# fill_mode = "wrap"
datagen = ImageDataGenerator(width_shift_range=0.5, fill_mode="wrap")
show_flow_image(datagen, x, 10)

# %%
# cval = 100
datagen = ImageDataGenerator(width_shift_range=0.5, fill_mode="constant", cval=100)
show_flow_image(datagen, x, 10)

# %%
# cval = 200
datagen = ImageDataGenerator(width_shift_range=0.5, fill_mode="constant", cval=200)
show_flow_image(datagen, x, 10)

# %%
# horizontal_flip = True
datagen = ImageDataGenerator(horizontal_flip=True)
show_flow_image(datagen, x, 10)

# %%
# vertical_flip = True
datagen = ImageDataGenerator(vertical_flip=True)
show_flow_image(datagen, x, 10)

# %%
# rescale = 1./255
datagen = ImageDataGenerator(rescale=1./255)
show_flow_image(datagen, x, 10)
